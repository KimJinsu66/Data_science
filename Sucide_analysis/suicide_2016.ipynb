# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("CSV파일/suicide_2016.csv")
#data.head()
#data.info(10)

#print(type(data))
data.dropna(how = "all")
data.fillna(0)
# Out:
# C:\Users\GSE\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (117,130,163,174,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       CTYPE  M_SUI_TOTAL    MH  E_RES  E_ADVI  E_PARTT  E_ALLWN  GRADE  \
# 0       대도시            1   중학교      1       5        1        1      1
# 1       대도시            1   중학교      1       1        2       16      1
# 2       대도시            1   중학교      1       2        1        3      1
# 3       대도시            1   중학교      1       7        1        2      1
# 4       대도시            1   중학교      1       2        1        8      1
# 5       대도시            1   중학교      1       7        1        2      1
# 6       대도시            1   중학교      1       4        1        2      1
# 7       대도시           -1   중학교      1       2        1        1      1
# 8       대도시            1   중학교      1       2        1        2      1
# ...

# %%
data['INT_WD_MM'][4]
# Out:
# ' '

# %%
val_data = pd.read_csv("CSV파일/2016자살변수정보.csv")
val_data.head()
#s = "YEAR"
# Out:
#        us w  문자  24  0        변수이름  지정않음 지정않음.1  8   왼쪽     명목형  입력
# 0     mod_d  문자  36  0   최종 DB 수정일  지정않음   지정않음  8   왼쪽     명목형  입력
# 1      YEAR  숫자   4  0        조사연도  지정않음   지정않음  8  오른쪽  알 수 없음  입력
# 2      CITY  문자  12  0          시도  지정않음   지정않음  8   왼쪽     명목형  입력
# 3     CTYPE  문자  24  0        도시규모  지정않음   지정않음  8   왼쪽     명목형  입력
# 4  CTYPE_SD  문자  24  0  도시규모(표본설계)  지정않음   지정않음  8   왼쪽     명목형  입력

# %%
data =data.drop(["CTYPE"], axis=1)
data = data.drop(["MH"], axis=1)
data = data.drop(["GROUP"], axis=1)
data = data.drop(["HT"], axis=1)
data = data.drop(["WT"], axis=1)
data = data.drop(["M_SUI_CON"], axis=1)
data = data.drop(["M_SUI_PLN"], axis=1)
data = data.drop(["M_SUI_ATT"], axis=1)
#data = data.drop(['INT_WD_MM'], axis =1) # 일단 제거

# %%
list = []
for i in range(len(data.columns)):
    val = data.columns[i]    
    if data[val].dtype == object:
        list.append(val)

        
print(list)
# Out:
# ['F_DRINK_K', 'PA_WLK_MM', 'PA_SWD_S', 'PA_SWD_N', 'PA_SWK_S', 'PA_SWK_N', 'M_SLP_HR', 'M_SLP_MM', 'M_WK_HR', 'M_WK_MM', 'AC_FAGE', 'TC_FAGE', 'TC_DAGE', 'TC_EC_FAGE', 'S_FAGE', 'S_PREG', 'S_ABOR', 'INT_WD_MM1', 'INT_WD_MM2', 'INT_WK_MM1', 'INT_WK_MM2', 'AGE', 'AGE_M']

# %%
data = data.replace(['1',1,' ','9999',9999], [1,1,0,0,0])

# %%
list = []
for i in range(len(data.columns)):
    val = data.columns[i]    
    if data[val].dtype == object:
        list.append(val)

        
print(list)
# Out:
# []

# %%
corr_matrix = data.corr()
corr_matrix["M_SUI_TOTAL"].sort_values(ascending=False)
# Out:
# M_SUI_TOTAL    1.000000
# AC_SND_2       0.098122
# AC_SND_4       0.079950
# M_SLP_HR       0.066594
# M_SLP_HR_K     0.058131
# AC_ALLOW       0.057065
# AC_SND_3       0.056492
# F_BR           0.053564
# TC_CSN         0.051539
# AC_SND_1       0.050886
# E_FM_M_3       0.043312
# E_FM_F_1       0.038376
# PA_VIG         0.037838
# PA_PE_FQ       0.037118
# M_WK_HR        0.036227
# E_KRN_F        0.033838
# E_EDU_F        0.033131
# TC_TAD_NO_5    0.028512
# AGE_M          0.028181
# F_FRUIT        0.027844
# AGE            0.027483
# PA_MSC         0.025180
# TC_AD_TV_2     0.022082
# PA_TOT         0.021518
# F_EDU          0.020743
# E_FM_OBS_7     0.014910
# MH             0.014627
# I_SCH_ED2      0.011901
# E_FM_GF_5      0.009747
# NO1            0.008445
#                  ...
# TC_LT         -0.071484
# TC_AMNT       -0.072228
# S_SI          -0.072662
# Unnamed: 11   -0.074134
# S_SI_AC       -0.074748
# TC_SND_S      -0.075050
# AC_PLC_1      -0.076478
# ...

# %%
list = []
for i in range(len(data.columns)):
    val = data.columns[i]    
    if data[val].dtype == object:
        list.append(val)

        
print(list)
# Out:
# []

# %%
#object type 확인
count = 0 
for i in range(len(data.columns)):
    val = data.columns[i]    
    if data[val].dtype == object:
        print(val)
        data[val] = data[val].astype(int)
        
        print(data[val].unique())
    elif data[val].dtype == float:
        data[val] = data[val].astype(float)
    else:
        pass

print(count)
# Out:
# 0

# %%
# null 개수 확인
data.isnull().sum()
# Out:
# M_SUI_TOTAL    0
# E_RES          0
# E_ADVI         0
# E_PARTT        0
# E_ALLWN        0
# GRADE          0
# E_SES          0
# FPC            0
# PR_HT          0
# PR_BI          0
# PR_HD          0
# PR_OH          0
# F_BR           0
# F_FRUIT        0
# F_DRINK_K      0
# F_DRINK_RS     0
# F_SODA         0
# F_CAFFEINE     0
# F_SWDRINK      0
# F_FASTFOOD     0
# F_VEG          0
# F_MILK         0
# F_EDU          0
# F_FFOOD_K1     0
# F_FFOOD_K2     0
# F_FFOOD_K3     0
# F_FFOOD_K4     0
# F_FFOOD_K5     0
# F_FFOOD_K6     0
# F_FFOOD_K7     0
#               ..
# ECZ_DG_LT      0
# ECZ_DG_YR      0
# INT_WD         0
# INT_WD_MM1     0
# INT_WD_MM2     0
# INT_WK         0
# INT_WK_MM1     0
# INT_WK_MM2     0
# AGE            0
# AGE_M          0
# E_FM_F_1       0
# E_FM_SF_2      0
# E_FM_M_3       0
# E_FM_SM_4      0
# E_FM_GF_5      0
# E_FM_GM_6      0
# E_FM_OBS_7     0
# E_FM_YBS_8     0
# E_FM_NO_9      0
# E_LT_F         0
# E_LT_SF        0
# ...

# %%
# cancer to DataFrame
import pandas as pd
import numpy as np

# x: data / y : 결과값

x = data.drop(["M_SUI_TOTAL"], axis=1)
y = data["M_SUI_TOTAL"].astype(int)

# %%
#Create Test Set
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# 데이터를 test data 20% training data를 80%로 나눈다.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=20)

print(len(x_train))
print(len(x_test))
#print(y_train)
#print(y_test)
# Out:
# 52422
# 13106

# %%
# data scaling StandardScaler 사용
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x = sc.fit_transform(x) # x_train data scaling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import statsmodels.api as sm
from scipy import stats

log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)



x2 = sm.add_constant(x)
y_pred = log_reg.predict(x_test)

model = sm.OLS(y, x)
result = model.fit()
#print(result.summary())# summary함수 하면 로지스틱 회귀분석 결과 나옴
# Out:
# C:\Users\GSE\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(result.summary())
#print(result.summary2().tables[1])# summary함수 하면 로지스틱 회귀분석 결과 나옴
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:            M_SUI_TOTAL   R-squared (uncentered):                   0.139
# Model:                            OLS   Adj. R-squared (uncentered):              0.136
# Method:                 Least Squares   F-statistic:                              51.44
# Date:                Sun, 27 Oct 2019   Prob (F-statistic):                        0.00
# Time:                        21:55:15   Log-Likelihood:                         -88077.
# No. Observations:               65528   AIC:                                  1.766e+05
# Df Residuals:                   65323   BIC:                                  1.784e+05
# Df Model:                         205
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
count = 1
val_count = 0
val_list = []
val_name = []
p_values = result.summary2().tables[1]['P>|t|']
#print(type(p_values.values[2]) <0.05)

for i in range(len(p_values)):
    if round(p_values[i],4) < 0.05:
        print(count , ":",round(p_values[i],4))
        val_count +=1
        val_list.append(count)
    count +=1
print("변수 개수 : ",val_count)
print("변수 위치 : ",val_list)
for i in val_list:
    val_name.append(data.columns[i])


for i in val_name:
    #print(type(i))
    #print(val_data["변수이름"][0])
    for j in range(len(val_data)):
        #print(val_data["OBS"][i],",",val_data["변수이름"][i])
        if val_data["us w"][j] == i:
            print(val_data["변수이름"][j])
print(val_name)

print('정확도 :', metrics.accuracy_score(y_test, y_pred))
# Out:
# 2 : 0.0
# 5 : 0.0
# 10 : 0.0
# 11 : 0.0259
# 17 : 0.0024
# 46 : 0.0154
# 58 : 0.0071
# 62 : 0.0
# 72 : 0.0
# 73 : 0.0
# 79 : 0.0467
# 89 : 0.0
# 106 : 0.0057
# 107 : 0.0059
# 113 : 0.0019
# 152 : 0.0155
# 159 : 0.0126
# 170 : 0.0034
# 171 : 0.0105
# 183 : 0.0152
# 변수 개수 :  20
# 변수 위치 :  [2, 5, 10, 11, 17, 46, 58, 62, 72, 73, 79, 89, 106, 107, 113, 152, 159, 170, 171, 183]
# 고민 상담자
# 학년
# 주관적 행복
# 주관적 구강건강 인지
# 최근 7일 동안 고카페인 음료 섭취빈도
# 최근 7일 동안 주말 앉아서 보낸 시간_학습목적
# 최근 30일 동안 체중조절방법 7)식사 후 구토
# 평상시 스트레스 인지
# 최근 12개월 동안 슬픔&절망감 경험
# 최근 12개월 동안 자살 시도로 병원 치료 경험
# 현재 사용 구강관리용품 4)전동칫솔
# 최근 12개월 동안 증상 6)입냄새
# 이어폰 또는 핸드폰 사용으로 인한 손상 병원치료 경험
# 최근 12개월 동안 폭력으로 인한 병원 치료 경험
# 최근 12개월 동안 경험 2)혼자서 음주
# 친한 친구 현재 흡연
# 성별
# 습관적 또는 일부러 약물 경험
# 평생 약물 경험
# 주말_학습목적이외_인터넷 이용 총 시간(분)
# ['E_ADVI', 'GRADE', 'PR_HD', 'PR_OH', 'F_CAFFEINE', 'PA_SWK_S', 'WC_MN_M07', 'M_STR', 'M_SAD', 'M_SUI_TRT', 'O_OCP4', 'O_SYMP6', 'I_EAR_TRT', 'V_TRT', 'AC_CRF2', 'TC_CSBF', 'SEX', 'DR_EXP', 'DR_LT', 'INT_WK_MM2']
# ...

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix

sv = svm.SVC(gamma = 'auto',kernel = 'rbf')
sv.fit(x_train,y_train)
sy_pred = svm.predict(x_test)
print(confusion_matrix(y_test,y_pred))
#print(confusion_matrix(y_test,y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
#
clf = RandomForestClassifier(n_estimators=50,max_depth = 7 ,random_state=2) # 나무의 개수 = 50인 RandomForest
clf.fit(x_train,y_train)
cy_pred = clf.predict(x_test)

# %%
# DecisionTree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

dtc = DecisionTreeClassifier(criterion = 'entropy', max_depth = 7) 
#  entropy를 기준으로 사용하고 최대 깊이 7인 DecisionTree.

dtc.fit(x_train,y_train) 
dy_pred = dtc.predict(x_test)
print(confusion_matrix(y_test,dy_pred))
# Out:
# [[  372  1294]
#  [  269 10073]]

# %%
# 특징 중요도 측정
for name, score in zip(data, dtc.feature_importances_):
    print(name, score)
    if name == "M_SUI_TOTAL":
        pass
    else:
        if score == 0:
            data = data.drop([name], axis=1)
# Out:
# M_SUI_TOTAL 0.0
# E_BORN_F 0.0
# MH 0.0038966668033792976
# CLUSTER 0.0005219104515951202
# CTYPE 0.0
# E_S_RCRD 0.004085451065716662
# E_SES 0.0008353856828974839
# E_RES 0.001073302345331194
# GRADE 0.0
# E_BORN_M 0.0
# E_EDU_M 0.0
# Unnamed: 11 0.0
# E_BORN_M.1 0.001397546359951748
# W 0.002884876975425249
# FPC 0.02305265224363532
# PR_HT 0.0018150119590209087
# PR_BI 0.0
# F_BR 0.0007961894463227587
# F_FRUIT 0.0
# F_SODA 0.0
# F_SWDRINK 0.0005094347271805293
# F_FASTFOOD 0.0
# F_EDU 0.0010263602820445202
# PA_TOT 0.001705371172770479
# PA_VIG 0.0006825384145922848
# PA_MSC 0.0
# PA_SWD_S 0.0024314746538233144
# PA_SWD_N 0.0015578541559702482
# PA_SWK_S 0.0015810786979669556
# PA_SWK_N 0.002161023759428721
# PA_PE_FQ 0.0006016818946878502
# WC_MN 0.1415832214840618
# M_STR 0.0007747175789357541
# M_SLP_EN 0.0
# M_SLP_HR 0.0005170437884602947
# M_SLP_MM 0.0
# M_WK_HR 0.0
# M_WK_MM 0.0015893312899362111
# M_SLP_HR_K 0.0
# M_SLP_MM_K 0.0010099061572712803
# ...

# %%
data.info(10)

# %%
corr_matrix = data.corr()
corr_matrix["M_SUI_TOTAL"].sort_values(ascending=False)

# %%
# 예측값 측정
#random_forest_pred = clf.predict(x_test) # Random Forest의 test값에 대한 예측 값
Dct_pred = dtc.predict(x_test)# Decision Tree의 test값에 대한 예측 값
#svm_pred = sv.predict(x_test)# SVM의 test값에 대한 예측 값

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=20)

print(len(x_train))
print(len(x_test))
# Out:
# 49820
# 12456

# %%
corr_matrix["M_SUI_CON"]

"""
for i in corr_matrix["M_SUI_CON"]
    if i < 0 :
        data = data.drop[]
        """

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix

sv = svm.SVC(gamma = 'auto',kernel = 'rbf')
sv.fit(x_train,y_train)
sy_pred = svm.predict(x_test)
print(confusion_matrix(y_test,y_pred))
#print(confusion_matrix(y_test,y_pred))

# %%
# F-1 score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

print("Decision Tree accuracy %.2f" %accuracy_score(y_test,Dct_pred))# Decision Tree 값 출력
#print("Random Forest accuracy %.2f" %accuracy_score(y_test,random_forest_pred))# Random Forest 값 출력
#print("SVM accuracy %.2f" %accuracy_score(y_test,svm_pred))# SVM 값 출력

print("Decision f-1 score %.2f" %f1_score(y_test,Dct_pred))# Decision Tree 값 출력
#print("Random f-1 score %.2f" %f1_score(y_test,random_forest_pred))# Random Forest 값 출력
#print("SVM f-1 score %.2f" %f1_score(y_test,svm_pred))# SVM 값 출력
# Out:
# Decision Tree accuracy 0.90
# Decision f-1 score 0.95
